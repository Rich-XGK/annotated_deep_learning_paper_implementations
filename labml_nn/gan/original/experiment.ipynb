# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/gan/original/experiment.ipynb)
#
# ## DCGAN
#
# This is an experiment training DCGAN model.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn

# %% [markdown]
# Imports

# %%
from labml import experiment
from labml_nn.gan.original.experiment import Configs

# %% [markdown]
# Create an experiment

# %%
experiment.create(name="mnist_gan")

# %% [markdown]
# Initialize configurations

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf,
                   {'label_smoothing': 0.01})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
with experiment.start():
    conf.run()
# Out:
# <pre style="overflow-x: scroll;"><strong><span style="color: #DDB62B">No labml server url specified. Please start a labml server and specify the URL. Docs: https://github.com/labmlai/labml/tree/master/app</span></strong></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/Xgk/WorkSpace/annotated_deep_learning_paper_implementations/labml_nn/gan/original/experiment.ipynb 单元格 13 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22413130302d50726976617465227d/home/Xgk/WorkSpace/annotated_deep_learning_paper_implementations/labml_nn/gan/original/experiment.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> with experiment.start():
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22413130302d50726976617465227d/home/Xgk/WorkSpace/annotated_deep_learning_paper_implementations/labml_nn/gan/original/experiment.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     conf.run()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:269, in TrainValidConfigs.run(self)
#     267 _ = self.trainer
#     268 for _ in self.training_loop:
# --> 269     self.run_step()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:257, in TrainValidConfigs.run_step(self)
#     255 with self.mode.update(is_train=True):
#     256     with tracker.namespace('train'):
# --> 257         self.trainer()
#     258 if self.validator:
#     259     with tracker.namespace('valid'):
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:140, in Trainer.__call__(self)
#     138         sm.on_epoch_start()
#     139 with torch.set_grad_enabled(self.mode.is_train):
# --> 140     self.__iterate()
#     142 if self._batch_index.completed:
#     143     for sm in self.state_modules:
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:151, in Trainer.__iterate(self)
#     149     monit.progress(0)
#     150 while not self._batch_index.iteration_completed:
# --> 151     batch = next(self.__iterable)
#     153     self.step(batch, self._batch_index)
#     155     self._batch_index.step()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/torchvision/datasets/mnist.py:142, in MNIST.__getitem__(self, index)
#     138 img, target = self.data[index], int(self.targets[index])
#     140 # doing this so that it is consistent with all other datasets
#     141 # to return a PIL Image
# --> 142 img = Image.fromarray(img.numpy(), mode="L")
#     144 if self.transform is not None:
#     145     img = self.transform(img)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/PIL/Image.py:3093, in fromarray(obj, mode)
#    3090     else:
#    3091         obj = obj.tostring()
# -> 3093 return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/PIL/Image.py:3000, in frombuffer(mode, size, data, decoder_name, *args)
#    2998     args = mode, 0, 1
#    2999 if args[0] in _MAPMODES:
# -> 3000     im = new(mode, (1, 1))
#    3001     im = im._new(core.map_buffer(data, size, decoder_name, 0, args))
#    3002     if mode == "P":
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/PIL/Image.py:2914, in new(mode, size, color)
#    2912     im.palette = ImagePalette.ImagePalette()
#    2913     color = im.palette.getcolor(color)
# -> 2914 return im._new(core.fill(mode, size, color))
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/PIL/Image.py:510, in Image._new(self, im)
#     508 new.mode = im.mode
#     509 new._size = im.size
# --> 510 if im.mode in ("P", "PA"):
#     511     if self.palette:
#     512         new.palette = self.palette.copy()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/training_loop.py:175, in TrainingLoop.__handler(self, sig, frame)
#     173 self.__finish()
#     174 logger.log('Killing loop...', Text.danger)
# --> 175 self.old_handler(sig, frame)
#
# KeyboardInterrupt:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。请查看单元格中的代码，以确定故障的可能原因。有关详细信息，请单击 <a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>。有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
