# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/gan/wasserstein/experiment.ipynb)
#
# ## DCGAN
#
# This is an experiment training DCGAN model.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn

# %% [markdown]
# Imports

# %%
from labml import experiment
from labml_nn.gan.wasserstein.experiment import Configs

# %% [markdown]
# Create an experiment

# %%
experiment.create(name="mnist_wgan")

# %% [markdown]
# Initialize configurations

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf,
                   {
                       'discriminator': 'cnn',
                       'generator': 'cnn',
                       'label_smoothing': 0.01,
                       'generator_loss': 'wasserstein',
                       'discriminator_loss': 'wasserstein',
                   })
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
with experiment.start():
    conf.run()
# Out:
# <pre style="overflow-x: scroll;"><strong><span style="color: #DDB62B">No labml server url specified. Please start a labml server and specify the URL. Docs: https://github.com/labmlai/labml/tree/master/app</span></strong></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:153, in Trainer.__iterate(self)
#     151 batch = next(self.__iterable)
# --> 153 self.step(batch, self._batch_index)
#     155 self._batch_index.step()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_nn/gan/original/experiment.py:143, in Configs.step(self, batch, batch_idx)
#     142 # Train the discriminator
# --> 143 with monit.section("discriminator"):
#     144     # Get discriminator loss
#     145     loss = self.calc_discriminator_loss(data)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/monitor/sections.py:88, in Section.__exit__(self, exc_type, exc_val, exc_tb)
#      86     self.track_progress()
# ---> 88 self._monitor.section_exit(self)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/monitor/__init__.py:228, in Monitor.section_exit(self, section)
#     226     raise RuntimeError("Impossible")
# --> 228 self.__log_line()
#     229 self.__sections.pop(-1)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/monitor/__init__.py:204, in Monitor.__log_line(self)
#     202 if (self.__is_looping and
#     203         not (self.__sections and isinstance(self.__sections[-1], OuterSection))):
# --> 204     self.__log_looping_line()
#     205     return
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/monitor/__init__.py:199, in Monitor.__log_looping_line(self)
#     198 if not self.__is_silent:
# --> 199     logger().log(parts, is_new_line=False)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/logger/__init__.py:24, in Logger.log(self, parts, is_new_line, is_reset)
#      23 for d in self.__destinations:
# ---> 24     d.log(parts, is_new_line=is_new_line, is_reset=is_reset)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/logger/destinations/console.py:44, in ConsoleDestination.log(self, parts, is_new_line, is_reset)
#      43 if text:
# ---> 44     self.print("\r" + " " * 100 + "\r" + text, end_char)
#      45 else:
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/logger/destinations/console.py:54, in ConsoleDestination.print(self, text, end_char)
#      53 else:
# ---> 54     API_LOGS.outputs(logger_=text + end_char)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/api/logs.py:84, in ApiLogs.outputs(self, stdout_, stderr_, logger_)
#      80 def outputs(self, *,
#      81             stdout_: str = '',
#      82             stderr_: str = '',
#      83             logger_: str = ''):
# ---> 84     with self.lock:
#      85         if stdout_ != '':
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/training_loop.py:175, in TrainingLoop.__handler(self, sig, frame)
#     174 logger.log('Killing loop...', Text.danger)
# --> 175 self.old_handler(sig, frame)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /home/Xgk/WorkSpace/annotated_deep_learning_paper_implementations/labml_nn/gan/wasserstein/experiment.ipynb 单元格 13 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22413130302d50726976617465227d/home/Xgk/WorkSpace/annotated_deep_learning_paper_implementations/labml_nn/gan/wasserstein/experiment.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> with experiment.start():
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22413130302d50726976617465227d/home/Xgk/WorkSpace/annotated_deep_learning_paper_implementations/labml_nn/gan/wasserstein/experiment.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     conf.run()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:269, in TrainValidConfigs.run(self)
#     267 _ = self.trainer
#     268 for _ in self.training_loop:
# --> 269     self.run_step()
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:257, in TrainValidConfigs.run_step(self)
#     255 with self.mode.update(is_train=True):
#     256     with tracker.namespace('train'):
# --> 257         self.trainer()
#     258 if self.validator:
#     259     with tracker.namespace('valid'):
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:140, in Trainer.__call__(self)
#     138         sm.on_epoch_start()
#     139 with torch.set_grad_enabled(self.mode.is_train):
# --> 140     self.__iterate()
#     142 if self._batch_index.completed:
#     143     for sm in self.state_modules:
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml_helpers/train_valid.py:147, in Trainer.__iterate(self)
#     146 def __iterate(self):
# --> 147     with monit.section(self.name, is_partial=True, is_track=self.is_track_time):
#     148         if self._batch_index.idx == 0:
#     149             monit.progress(0)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/monitor/sections.py:88, in Section.__exit__(self, exc_type, exc_val, exc_tb)
#      85 if self.is_track:
#      86     self.track_progress()
# ---> 88 self._monitor.section_exit(self)
#
# File ~/miniconda3/envs/labml_nn/lib/python3.10/site-packages/labml/internal/monitor/__init__.py:226, in Monitor.section_exit(self, section)
#     223     raise RuntimeError("Impossible")
#     225 if section is not self.__sections[-1]:
# --> 226     raise RuntimeError("Impossible")
#     228 self.__log_line()
#     229 self.__sections.pop(-1)
#
# RuntimeError: Impossible
